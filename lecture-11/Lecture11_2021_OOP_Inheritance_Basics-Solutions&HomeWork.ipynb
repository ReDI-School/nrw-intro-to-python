# %% [markdown]
# # so far -   function, loop, variable declaration : Procedural Programming
#
# code as a sequence step
#
# 1 person's schedule : wakeup-> jumping up into the S-Bahn -> going to the library-> checking today's bitcoin price -> feeling drowsy -> Zzz...-> etc
#
# # If city planner?
# considering  17,912,134 people's schedule in NRW
# Trying to map out a sequence of actions for each individual would quickly get unsustainable.
# The more data it uses, the harder it is to think about as just a sequence of steps.

# %% [markdown]
# # Solution = Object-Oriented Programming
# Python is object oriented programming (OOP) language.
#
# Almost everything in Python is an object with its attributes and methods
# Objects are "instances" of classes.
# also can be termed as object "constructor" for creating objects

# %% [markdown]
# # Object? Class? What is that?

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %% [markdown]
# Class = a blueprint of the objects (memory is not needed)
# Classes are essentially a template to create your objects
#
# Object = declaration of using class in real. memory is assigned once you create object
# Object is an encapsulation of variables and functions into a single entity
#
# Objects get their variables and functions from classes

# %% [markdown]
# # Class anatomy : attributes and methods
# class = a blueprint of the objects = consist of attributes, methods

# %% [markdown]
# * Create a Class & Create Object

# %%
# defining class 
class MyClass:
  x = 5

# creating object
p1 = MyClass()

# how to access : dot operator 
print(p1.x)
# Out:
# 5

# %% [markdown]
# # Class anatomy : the  __init__ constructor

# %% [markdown]
# ### In practice:  built-in  __init__() function
# The examples above are classes and objects in their simplest form, and are not really useful in real life applications.
#
# To understand the meaning of classes we have to understand the built-in __init__() function.
#
# All classes have a function called __init__(), which is always executed when the class is being initiated.
#
# Use the __init__() function to assign values to object properties, or other operations that are necessary to do when the object is being created:

# %%
# defining class with constructor 
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

# creating object = the class is being initiated
p1 = Person("John", 36)

# how to access : dot operator 
print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %% [markdown]
# FYI :   __init__() function is called automatically every time the class is being used to create a new object.

# %% [markdown]
# ### Object Methods
# Objects can also contain methods. Methods in objects are functions that belong to the object.
#
# Let us create a method in the Person class:

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)

p1 = Person("John", 36)
p1.myfunc()

# %% [markdown]
# The self parameter is a reference to the current instance of the class, and is used to access variables that belong to the class.

# %% [markdown]
# ### The self Parameter
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
#
# It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class:

# %%
class Person:
  def __init__(mysillyobject, name, age):
    mysillyobject.name = name
    mysillyobject.age = age

  def myfunc(abc):
    print("Hello my name is " + abc.name)

p1 = Person("John", 36)
p1.myfunc()
# Out:
# Hello my name is John

# %% [markdown]
# ### Modify Object Properties

# %%
p1.name = "Sharky"
p1.myfunc()
# Out:
# Hello my name is Sharky

# %% [markdown]
# ### Delete Object Properties
# You can delete properties on objects by using the del keyword

# %%
del p1.name
p1.myfunc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-db43b0d81a47> in <module>
#       1 del p1.name
# ----> 2 p1.myfunc()
#
# <ipython-input-17-b5545cdeb3eb> in myfunc(abc)
#       5
#       6   def myfunc(abc):
# ----> 7     print("Hello my name is " + abc.name)
#       8
#       9 p1 = Person("John", 36)
#
# AttributeError: 'Person' object has no attribute 'name'

# %% [markdown]
# ### Delete Objects

# %%
del p1
p1.myfunc()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-97ebd40681f1> in <module>
#       1 del p1
# ----> 2 p1.myfunc()
#
# NameError: name 'p1' is not defined

# %% [markdown]
# ### The pass Statement
# class definitions cannot be empty, but if you for some reason have a class definition with no content, put in the pass statement to avoid getting an error.

# %%
class Person:
  pass

# %% [markdown]
# # Inheritance : Child and Parent
# Inheritance allows us to define a class that inherits all the methods and properties from another class.
#
# Parent class is the class being inherited from, also called base class.
#
# Child class is the class that inherits from another class, also called derived class.

# %% [markdown]
# ### Create a Parent Class
# Any class can be a parent class, so the syntax is the same as creating any other class:

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()
# Out:
# John Doe

# %% [markdown]
# ### Create a Child Class
# To create a class that inherits the functionality from another class, send the parent class as a parameter when creating the child class:

# %%
class Student(Person):
  pass

# %%
# using Student class to create an object x, and then execute the printname method
x = Student("Mike", "Olsen")
x.printname()
# Out:
# Mike Olsen

# %% [markdown]
# ### Add the __init__() Function
# So far we have created a child class that inherits the properties and methods from its parent.
#
# We want to add the __init__() function to the child class (instead of the pass keyword).
#
# Note: The __init__() function is called automatically every time the class is being used to create a new object.

# %%
class Student(Person):
  def __init__(self, fname, lname):
    pass

# %% [markdown]
# When you add the __init__() function, the child class will no longer inherit the parent's __init__() function.
#
# Note: The child's __init__() function overrides the inheritance of the parent's __init__() function.
#
# To keep the inheritance of the parent's __init__() function, add a call to the parent's __init__() function:

# %%
class Student(Person):
  def __init__(self, fname, lname):
    Person.__init__(self, fname, lname)

# %% [markdown]
# Now we have successfully added the __init__() function, and kept the inheritance of the parent class, and we are ready to add functionality in the __init__() function.

# %% [markdown]
# ### Use the super() Function
# Python also has a super() function that will make the child class inherit all the methods and properties from its parent:

# %%
class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)

# %% [markdown]
# By using the super() function, you do not have to use the name of the parent element, it will automatically inherit the methods and properties from its parent.

# %% [markdown]
# ### Add Properties

# %%
class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)
    self.graduationyear = 2019

# %% [markdown]
# In the example below, the year 2019 should be a variable, and passed into the Student class when creating student objects. To do so, add another parameter in the __init__() function:

# %%
class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

x = Student("Mike", "Olsen", 2019)

# %% [markdown]
# ### Add Methods

# %%
class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

  def welcome(self):
    print("Welcome", self.firstname, self.lastname, "to the class of", self.graduationyear)

# %% [markdown]
# If you add a method in the child class with the same name as a function in the parent class, the inheritance of the parent method will be overridden.

# %% [markdown]
# # Exercise : Inheritance

# %% [markdown]
# # It's your turn
